# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../RedbackRaceData/NewSlipToFrontRebound.csv')

# %%
df.plot.scatter(x='AvgSlip', y='Front_Rebound')
# Out:
# <AxesSubplot:xlabel='AvgSlip', ylabel='Front_Rebound'>
