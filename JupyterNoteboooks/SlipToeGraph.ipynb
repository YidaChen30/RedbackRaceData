# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('RedBackProj/RedbackRaceData/LapToSlipPlotWithToe.csv')

# %%
df.plot.scatter(x='AvgSlip', y='AvgLap')
# Out:
# <AxesSubplot:xlabel='AvgSlip', ylabel='AvgLap'>

# %%
df = pd.read_csv('RedBackProj/RedbackRaceData/LTSToeFL.csv')

# %%
df.plot.scatter(x='AvgSlip', y='AvgLap')
# Out:
# <AxesSubplot:xlabel='AvgSlip', ylabel='AvgLap'>
