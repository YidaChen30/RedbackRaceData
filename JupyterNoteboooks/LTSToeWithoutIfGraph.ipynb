# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
df = pd.read_csv('../RedbackRaceData/LTSToeWithoutIf.csv')
# This graph takes in all rows of output in file, with this simple line
# avgSlip += row['SlipAngle_FL'] + row['acsys.CS.ToeInDeg']

# %%
df.plot.scatter(x='AvgSlip', y='AvgLap')
# Out:
# <AxesSubplot:xlabel='AvgSlip', ylabel='AvgLap'>

# %%
df = pd.read_csv('../RedbackRaceData/LTSStaticToeWithoutIf.csv')
# Takes into a static toe which is the toe of the car when stationary
# avgSlip += row['SlipAngle_FL'] + setup_toe

# %%
df.plot.scatter(x='AvgSlip', y='AvgLap')
# Out:
# <AxesSubplot:xlabel='AvgSlip', ylabel='AvgLap'>

# %%
df = pd.read_csv('../RedbackRaceData/LTSStaticToeWithIf.csv')
 # This graph takes into account only with rows of steer > 45 degrees.
 # if abs(row['acsys.CS.Steer']) > 45: 
    # avgSlip += abs(row['SlipAngle_FL'] + setup_toe)

# %%
df.plot.scatter(x='AvgSlip', y='AvgLap')
# Out:
# <AxesSubplot:xlabel='AvgSlip', ylabel='AvgLap'>

# %%
df = pd.read_csv('../RedbackRaceData/LTSStaticToeWithIfAndSteer.csv')
# Takes into account steer in the avgSlip calculation 
# avgSlip += abs(row['acsys.CS.Steer']) / abs(row['SlipAngle_FL'] + setup_toe)

# %%
df.plot.scatter(x='AvgSlip', y='AvgLap')
# Out:
# <AxesSubplot:xlabel='AvgSlip', ylabel='AvgLap'>
