# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
df = pd.read_csv('../RedbackRaceData/LTSStaticToeUndersteer.csv')

# %%
df.plot.scatter(x='AvgSlip', y='AvgLap')
# Out:
# <AxesSubplot:xlabel='AvgSlip', ylabel='AvgLap'>
