# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df.plot.scatter(x='AvgSlip', y='ARB_Front')
# Out:
# <AxesSubplot:xlabel='AvgSlip', ylabel='ARB_Front'>

# %%
df = pd.read_csv('../RedbackRaceData/NewSlipToFrontTyrePressure.csv')

# %%
df.plot.scatter(x='AvgSlip', y='Front_TyrePressure')
# Out:
# <AxesSubplot:xlabel='AvgSlip', ylabel='Front_TyrePressure'>

# %%
df = pd.read_csv('../RedbackRaceData/NewSlipToRearTyrePressure.csv')

# %%
df.plot.scatter(x='AvgSlip', y='Rear_TyrePressure')
# Out:
# <AxesSubplot:xlabel='AvgSlip', ylabel='Rear_TyrePressure'>

# %%
df = pd.read_csv('../RedbackRaceData/NewSlipToFrontRearTyrePressure.csv')

# %%
df.plot.scatter(x='AvgSlip', y='FrontRear_TyrePressure')
# Out:
# <AxesSubplot:xlabel='AvgSlip', ylabel='FrontRear_TyrePressure'>
