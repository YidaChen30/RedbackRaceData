# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../RedbackRaceData/SlipToInput/SlipToARB_Front.csv')

# %%
df.plot.scatter(x='AvgSlip', y='ARB_Front')
# Out:
# <AxesSubplot:xlabel='AvgSlip', ylabel='ARB_Front'>

# %%
df = pd.read_csv('../RedbackRaceData/SlipToInput/NewSlipToARB_Front.csv')

# %%
df.plot.scatter(x='AvgSlip', y='ARB_Front')
# Out:
# <AxesSubplot:xlabel='AvgSlip', ylabel='ARB_Front'>

# %%
df = pd.read_csv('../RedbackRaceData/SlipToInput/NewSlipToARB_Rear.csv')

# %%
df.plot.scatter(x='AvgSlip', y='ARB_Rear')
# Out:
# <AxesSubplot:xlabel='AvgSlip', ylabel='ARB_Rear'>

# %%
df = pd.read_csv('../RedbackRaceData/SlipToInput/NewSlipToARB_FrontRear.csv')

# %%
ax = df.plot.scatter(x='AvgSlip', y='ARB_FrontRear')
ax.set_ylim([-0.1, 6])
# Out:
# (-0.1, 6.0)

# %%
df = pd.read_csv('../RedbackRaceData/SlipToInput/NewSlipToDiff_Coast.csv')

# %%
df.plot.scatter(x='AvgSlip', y='Diff_Coast')
# Out:
# <AxesSubplot:xlabel='AvgSlip', ylabel='Diff_Coast'>

# %%
df = pd.read_csv('../RedbackRaceData/combineddata.csv')

# %%
df.plot.scatter(x='AvgSlip', y='suspensions_FRONT_TOE_OUT')
# Out:
# <AxesSubplot:xlabel='AvgSlip', ylabel='suspensions_FRONT_TOE_OUT'>

# %%
df = pd.read_csv('../RedbackRaceData/SlipToInput/NewSlipToARB_Front&DiffCoast.csv')

# %%
df.plot.scatter(x='AvgSlip', y='ARB_Front&DiffCoast')
# Out:
# <AxesSubplot:xlabel='AvgSlip', ylabel='ARB_Front&DiffCoast'>

# %%
df = pd.read_csv('../RedbackRaceData/SlipToInput/NewSlipToARB_FrontRear&DiffCoast.csv')

# %%
ax = df.plot.scatter(x='AvgSlip', y='ARB_FrontRear&DiffCoast')
# ax.set_ylim([-0.1, 1])

# %%
df = pd.read_csv('../RedbackRaceData/SlipToInput/NewSlipToARB_FrontRear&FrontToe.csv')

# %%
ax = df.plot.scatter(x='AvgSlip', y='ARB_FrontRear&FrontToe', title = 'Slip to ARB_FrontRear * Static Front Toe')
ax.set_ylim([-.003,0.012])
# Out:
# (-0.003, 0.012)

# %%
df = pd.read_csv('../RedbackRaceData/SlipToInput/NewSlipToARB_FrontRear&DiffCoast&FrontToe.csv')

# %%
ax = df.plot.scatter(x='AvgSlip', y='ARB_FrontRear&DiffCoast&FrontToe')
ax.set_ylim([-0.001, 0.0025])
# Out:
# (-0.001, 0.0025)

# %%
df = pd.read_csv('../RedbackRaceData/SlipToInput/NewSlipToARB_FrontRear&FrontToe&FrontBump.csv')

# %%
ax = df.plot.scatter(x='AvgSlip', y='ARB_FrontRear&FrontToe&FrontBump')
ax.set_ylim([-4.3, 15])
# Out:
# (-4.3, 15.0)

# %%
df = pd.read_csv('../RedbackRaceData/SlipToInput/NewSlipToARB_FrontRear&FrontToe&FrontBump&Diff_Coast.csv')

# %%
ax = df.plot.scatter(x='AvgSlip', y='ARB_FrontRear&FrontToe&FrontBump&Diff_Coast')
ax.set_ylim([-1, 6])
# Out:
# (-1.0, 6.0)

# %%
df = pd.read_csv('../RedbackRaceData/SlipToInput/NewSlipToARB_FrontRear&FrontToe&FrontBump&Front_Rebound.csv')

# %%
ax = df.plot.scatter(x='AvgSlip', y='ARB_FrontRear&FrontToe&FrontBump&Front_Rebound')
ax.set_ylim([-11000, 30000])
# Out:
# (-11000.0, 30000.0)

# %%
df = pd.read_csv('../RedbackRaceData/SlipToInput/NewSlipToARB_FrontRear&FrontToe&FrontBump&Diff_Coast&Front_Rebound.csv')

# %%
ax = df.plot.scatter(x='AvgSlip', y='ARB_FrontRear&FrontToe&FrontBump&Diff_Coast*Front_Rebound')
ax.set_ylim([-2000, 10000])
# Out:
# (-2000.0, 10000.0)
