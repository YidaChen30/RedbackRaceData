# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('RedBackProj/RedbackRaceData/SlipToARB_Rear.csv')

# %%
df.plot.scatter(x='AvgSlip', y='ARB_Rear')
# Out:
# <AxesSubplot:xlabel='AvgSlip', ylabel='ARB_Rear'>
