# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

def generatePlots():
    df = pd.read_csv('./combineddata.csv')
    i = 35
    #plt.scatter(df.iloc[:, -2] , df.iloc[:, -1])
    sns.regplot(x = df.iloc[:, -2], y = df.iloc[:, -1], ci=None, line_kws={"color": "orange"})
    plt.ylim([39500, 48000])
    plt.title(f'Graph {df.columns[i]}')

    plt.ylabel(f'{df.columns[i]}')

    #plt.ylabel('fastest lap time')
    plt.xlabel('Slip Angle')

    plt.show()

if __name__ == "__main__":
  generatePlots()

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

def generatePlots():
    df = pd.read_csv('./combineddata.csv')
    i = 24
    #plt.scatter(df.iloc[:, -2] , df.iloc[:, -1])
    sns.regplot(x = df.iloc[:, -2], y = (df.iloc[:, 13]), ci=None, line_kws={"color": "orange"})
    #plt.ylim([0.3, 1.4])
    plt.title(f'Graph {df.columns[i]}')

    plt.ylabel(f'{df.columns[i]}')

    #plt.ylabel('fastest lap time')
    plt.xlabel('Slip Angle')

    plt.show()

if __name__ == "__main__":
  generatePlots()
